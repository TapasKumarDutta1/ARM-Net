# %% [markdown]
# <a href="https://colab.research.google.com/github/greyhound101/gan_segmentation_FE/blob/main/cbam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
fnl_acc1=list(np.load('/content/final_accuracy_last_fold1_5e-5_wn.npy',allow_pickle=True).item().values())[0]
fnl_acc2=list(np.load('/content/final_accuracy_last_fold2_1e-4_wn.npy',allow_pickle=True).item().values())[0]
fnl_acc3=list(np.load('/content/final_accuracy_last_fold3_1e-4_wn.npy',allow_pickle=True).item().values())[0]
fnl_acc4=list(np.load('/content/final_accuracy_last_fold4_5e-5_wn.npy',allow_pickle=True).item().values())[0]
fnl_acc5=list(np.load('/content/final_accuracy_last_fold5_1e-4_wn.npy',allow_pickle=True).item().values())[0]
np.mean([fnl_acc1,fnl_acc2,fnl_acc3,fnl_acc4,fnl_acc5])
# Out:
# 0.9564441039126426

# %%
import os
import glob
for i in glob.glob('/content/*.npy'):
  os.remove(i)

# %%
tot_ans=[]
tot_pre=[]

# %%
from sklearn.metrics import confusion_matrix
ans_1=np.load('/content/answers_last_fold1_5e-5_wn.npy',allow_pickle=True).item()
fold_1_pre=np.load('/content/predictions_last_fold1_5e-5_wn.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
tot_ans.extend(ans_1)
tot_pre.extend(fold_1_pre)
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[112   0   0]
#  [  8 237   0]
#  [  9   1 175]]

# %%
ans_1=np.load('/content/answers_last_fold2_1e-4_wn.npy',allow_pickle=True).item()
fold_1_pre=np.load('/content/predictions_last_fold2_1e-4_wn.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
tot_ans.extend(ans_1)
tot_pre.extend(fold_1_pre)
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[156  11   0]
#  [  6 331   1]
#  [  5  11 158]]

# %%
ans_1=np.load('/content/answers_last_fold3_1e-4_wn.npy',allow_pickle=True).item()
fold_1_pre=np.load('/content/predictions_last_fold3_1e-4_wn.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
tot_ans.extend(ans_1)
tot_pre.extend(fold_1_pre)
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[135   3   1]
#  [ 14 217   0]
#  [  6   0 196]]

# %%
ans_1=np.load('/content/answers_last_fold4_5e-5_wn.npy',allow_pickle=True).item()
fold_1_pre=np.load('/content/predictions_last_fold4_5e-5_wn.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
tot_ans.extend(ans_1)
tot_pre.extend(fold_1_pre)
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[113   8   3]
#  [  2 321   2]
#  [  5   1 173]]

# %%
ans_1=np.load('/content/answers_last_fold5_1e-4_wn.npy',allow_pickle=True).item()
fold_1_pre=np.load('/content/predictions_last_fold5_1e-4_wn.npy',allow_pickle=True).item()
ans_1=list(ans_1.values())[0]
fold_1_pre=list(fold_1_pre.values())[0]
tot_ans.extend(ans_1)
tot_pre.extend(fold_1_pre)
print(confusion_matrix(ans_1,fold_1_pre))
# Out:
# [[143   4  19]
#  [ 12 273   2]
#  [  1   0 189]]

# %%
import seaborn as sns
from matplotlib import pyplot as plt
sns.heatmap(confusion_matrix(tot_ans,tot_pre),annot=True,cmap='Blues', fmt='g',xticklabels=['Meningioma', 'Glioma','Pituitary' ],yticklabels=['Meningioma', 'Glioma','Pituitary' ])
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.savefig('mobilenet.png')

# %%
history={}
history['fold1']=np.load('/content/history_last_fold1_5e-5_wn.npy',allow_pickle=True).item()
history['fold2']=np.load('/content/history_last_fold2_1e-4_wn.npy',allow_pickle=True).item()
history['fold3']=np.load('/content/history_last_fold3_1e-4_wn.npy',allow_pickle=True).item()
history['fold4']=np.load('/content/history_last_fold4_5e-5_wn.npy',allow_pickle=True).item()
history['fold5']=np.load('/content/history_last_fold5_1e-4_wn.npy',allow_pickle=True).item()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['accuracy'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('accuracy')
    plt.title('Training all layers')
    plt.show()

# %%
from matplotlib import pyplot as plt
for i in range(5):
    fold='fold'+str(i+1)
    fold1='fold_'+str(i+1)
    plt.plot(history[fold][fold1]['loss'])
    plt.title('loss for fold '+str(i))
    plt.xlabel('epoch')
    plt.ylabel('loss')
    plt.title('Training all layers')
    plt.show()
